# %%
from nltk.tokenize import word_tokenize
import re
import pandas as pd
from nltk.corpus import stopwords
import string

import nltk
nltk.download('stopwords')

emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]

delete_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r'[^\x00-\x7f]' #hex characters    
    #r"(?:[a-z][a-z'\-_]+[a-z])" # words with - and '
    #r'(?:[\w_]+)', # other words
    #r'(?:\S)' # anything else
]

tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
delete_re = re.compile(r'('+'|'.join(delete_str)+')', re.VERBOSE | re.IGNORECASE)

def tokenize(s):
    tokens = tokens_re.findall(s)
    tokens = [token for token in tokens if not delete_re.search(token)]   
    return tokens

data = pd.read_csv("Twitter/TestData.csv")
actual_data["text"] = data["text"]

punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['RT', 'via']

for tweet in actual_data.text:
    line = [term for term in tokenize(tweet) if term not in stop]
    line = ' '.join(line)
    print line
    

#tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
#print(tokenize(tweet))
# ['RT', '@marcobonzanini', ':', 'just', 'an', 'example', '!', ':D', 'http://example.com', '#NLP']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prati\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Dile al Noviesito tuyo que el es una P
#
#
#
# Temenan jaman sekarang Si A ngomongin Si B begini Si B ngomongin Si A begitu Besuk besuk nya si A Dan si
#
# Borrar una persona de tu vida es casi imposible la tienes que eliminar de Facebook de WhatsApp Twitter etc Lo
# Pop
#
#
#
#
# Facebook makes privacy data downloading deletion settings easier find
#
#
# ARMY Please DON'T UNFOLLOW April's fool day prank It's important BTS ranking Social
#
#
#
#
# U
# I getting things started hyphy House music Get attending GLOW A Blacklight Affair Th
#
#
#
#
#
#
#
#
#
#
#
# Who's watching sidelines wanting know little amazing news TERRA essenti
# link https
#
#
# Bike Riding Party
# PM
# What Come event watch Short Documentary Decriminalizing Lehig
# Basic Steps connecting WordPress RSS feed Twitter Facebook Social Media Sites How would
#
#
#
# Long lines love Glorias Addision
#
# I posted new video Facebook
#
#
#
#
# REPOST Still missing grey w white cat areas Pls rt watch share help find Suzy
# Will Ferrell deleted account Cambridge Analytica user-privacy scandal
#
# Noctis Lucis Caelum DLC Panelists Ric Destin
#
# Do smoke c one friend
#
# Bring home sissy Lana Westerlund
# Un espacio donde compartiremos escalofriantes temas del mundo paranormal
#
# I wish Strength face challenges Mars meets Saturn Capricorn Tomorrow
# Whats next Maine The Tri-Care freshness new gariants Betadine Fresh Bliss Daily Feminine Wash
#
#
# E para dizer de um modo mais direto Facebook e Twitter est ganhando dinheiro partir da repercuss discurso de
# Facebook udah ga aman banyak emak dan kawan kawannya
#
#
# LOOK Salubong sa Sta Rita de Cascia Parish Para aque City Photo courtesy YouScooper Marlo Cueto
#
#
# P scoa
# It's true Facebook Google Amazon Twitter Apple etc get information government could sh
#
# Hace un esta misma hora comenzaban los disturbios una fuerte represi n policial en inmediaciones del Cong
#
# GUYS I JUST SAW THIS ON FACEBOOK well entertainment page made video On My Block GUYS
# Facebook Twitter New XPS
# Happy Easter lovely people
# Happy Easter facebook friends familys l
#
# porque boa obra de arte assim ela fala tempo e fica fora tempo Ela fala com todos de todos os n veis de
#
#
#
# From lips God's ears
#
#
#
# Story shared social media The power retweet Facebook share
# I gave Facebook Lent I realized issue returning Easter I I standing rule
#
# sebel sama instagram ngeluhnya di twitter sebel sama facebook ngeluhnya di twitter sebel sama path ngeluhnya di twitter se
#
#
#
# Umm THERE'S A HACKER FROM RUSSIA WHO UM FACEBOOK Aww sweetheart handler call ACTUAL STRAIGHT ORD
#
# rd Day Madolduwa
# rd Day Madolduwa
#
# Saya bekerja ya untuk memenuhi kebutuhan saya dan keluagalah Bukan cari muka dan pekerjaannya saja Cukup Par
# URGENTE DELEGADO FRANCISCHINI E BOLSONARO APRESENTAM PROJETO PARA ACABAR COM BENEF CIOS MILION RIOS DE EX-PRESIDENTES FIM D
# link https
# Like Fanpage Facebook BNK The growth rate
# Easter Egg
#
#
# Become UFS Social Media Ambassador easy steps Upload seconds video telling us th
# Trashiest Things Ever Posted Facebook
#
# Google amp Facebook first please
# JAJA yo ahora mismo
#
# N estou conseguindo te chamar DM Chama chat Facebook ent
# en McCarthy's Irish Pub
# w
#
# Nunca perder el glamour
#
#
# Deeper
# rd World Farmer Thought-Provoking Simulator
# Shared Marilyn Bonnette's Time Line
#
#
# WE LL GET MOHAE SEASON IF ANY OF THESE MISSIONS IS ACCOMPLISHED VLIVE Youtube Facebook total views add
# Ankara Esenboga Airport ESB'den ankara Esenboga Havalimani'ya seyahat ediyor
#
# Pero dumating ka taught handle things na hindi maggive sa mga pagsubok sa buhay Please aware
#
# Facebook This information They BBC And sell FB No Of course Please help
# Embora n estivesse mais em meus planos estou feliz em ser pai mais uma vez em Alter Ch
#
#
#
#
#
# twitter facebook
# Ge talon una ulo
#
# Percent Of The Worlds Facebook Users Are In African Countries
#
# Problema morfossint tico n h concord ncia de n mero na ora subordinada objetiva direta reduzida de infinitiv
#
# Multiple photos added album rental readiness
#
#
#
#
# ASOBIBA UP
# facebook vs twitter
#
#
# LIBERA A ESTA TIERRA DE LAS GARRAS DEL MAL Venezolanos veneran al Nazareno de San Pablo
#
# FALA MELHOR P BLICO Algu quer tirar foto e conhecer MC POCAHONTAS Ent faz seguinte confirma presen ev
#
#
#
#
#
# Watch Mark Zuckerberg went Russia meet Putin's deputy person years later Russian operatives using
# I change spelling name Facebook I realized first April Savage
#
#
#
#
#
# Love projector
# facebook pior rede social
#
# Congrats Tony Roberts Hard work dedication created amazing results
#
#
#
#
# criminal behavior I call everyone political persuasions stand censorship fraud
# cant wait
#
# God love
#
#
# Facebook
# Facebook
#
#
# guerreira ate fim poucos saberiam enfrentar morte como ela enfrentou
#
# Stand Fight NRA Show support America's oldest civil rights organization Update profile pic
#
#
#
#
# Once Sunday Times championed great investigative journalism exposing Thalidomide scandal Israel's nuclear weapo
# B'z
# Me encontr en Facebook unas fotos de unos animales cazando todos los hice memes
# LA COMPA A HOLANDESA DE CAFE DEFIENDE LA GUERRA CIVIL Son solo opiniones personales de los nazionalistass que trabajan
# I extremely disliked Tucker Carlson selling LITTLE integrity gig Fox News But afte
# I extremely disliked Tucker Carlson selling LITTLE integrity gig Fox News But afte
# Facebook In Turmoil Employees In Uproar Over Executive's Leaked Memo
# EL ROTULADOR HABR SALIDO DE LA UACM DE L PEZ pezObrador
#
# Israel Defense Forces inbred convert Zionists
#
# Just heard guy gym say bought Facebook cheap I asked metric replied beca
#
#
# Mina Mason see u shortly
#
#
# TK product LIVE
#
#
#
#
# Hindi ako nag iisa sa last part Joanne character May something naman kasi talaga eh
#
#
#
#
#
#
# Toma cu
#
# Quem disse que eu tenho coragem kkkk
# Google Apple Facebook Amazon existen alternativas las G A F A
#
#
# Bakasyon like Kain Tulog Puyat No Money Facebook Twitter Instagram Youtube Boring Movie
#
#
#
# kindly Follow social media IG ht
#
# Erik Santos A grand salute OPM country best finest singers ASAPinoy Huwag na
# G e pa e ta p p p f
#
#
# Hola bienvenido Twitter aqu somos nacos como en Facebook Gracias Qu es esto Ah son las tendencias A
#
#
#
# Los datos personales en Facebook usados con fines pol ticos
# May Easter bring peace happiness home hearts Santhome Church Chennai
# Saw Facebook day I share good things I saw HAHAHAHAHA Someone edited
# Asco
# link https
#
#
#
#
#
# I'm perfectly open criticism Amazon predatory pricing etc interesting Facebook used Russi
#
#
#
# This script It read asshole coworker dickhead uncle wackjob saw Facebook millions
#
#
# I want make sure everyone crystal clear point think I'm mean Fuckface Von Clo
# Carlos Yasmin e Daniele olhem isso
# These two words pretty much sum March Paparazzi world My heart happy see ranks team
# CAER N UNO A UNO La lista de los delincuentes oficialistas que sancion el gobierno de Suiza
#
#
#
#
#
#
#
#
# Balleneros japoneses volvieron este bado puerto tras haber matado ballenas El Gobierno del Jap n se empe
#
#
# Euuuu queroooooo
# Breathtaking
#
# MINTI TAREK Detenidos en PoliCarabobo dicen que cifra de muertos supera los
#
# ARMY Please DON'T UNFOLLOW April's fool day prank It's important BTS ranking Social
#
#
# Piensa en los demas
#
#
#
#
# Advertisers threatened abandon Facebook Zuckerberg apologized mistakes company made
#
# El ej rcito que responde la extrema derecha israel asesina j venes ni os palestinos indefensos El gobierno
# Sue os que cantan
#
# Yes I
# Seee seee
# A HAPPY Wolverine
# GHARIALS featured latest issue BBC Dhritiman Mukherjee
#
# Seen Facebook I bring twitter I literally cried laughing minutes
# Seen Facebook I bring twitter I literally cried laughing minutes
#
#
#
#
# FB
#
#
# para eso gustabas putito igual que EPN
#
#
# senior Corbyn McDonnell staff members Facebook groups containing anti-semitic amp violent posts inc threats ki
# link https
#
# Devore California please share
# Maris inviting everyone grand launch Garnier Lazada Get Garnier products especially Maris's favorit
# M amp A rehearsal Sergei Tamara
# Pano maging friends sa facebook ang mga Atenista Edi ADMU K Bye
# selfie fans CR Linger oppa Facebook
#
#
# AHORA SI NO MONTA SHOW Familiares de v ctimas en Carabobo exigen Lacava dar la cara
# U
#
#
#
# Facebook plans crackdown ad targeting email without consent
#
# Aqu casual con mi amigo Miguel Angel Salsu
# Wishing Well Facebook page pm
# Facebook deber otorgar al xalape la reacci n de Me enchileseca dicho
#
#
#
#
#
# Sehun MLB store event Hong Kong
#
# live
#
#
#
#
#
# Ikutan amp dptin hadiahnya Caranya Follow instagram twitter amp LIKE FB Dinomarket RETWEET Wajib hukumnya Cara
# Don't think Jesus Christ feminist He protected accused women presented himse
# I'm vendor Toward back right
# So started messing around last night today I took tune amp restringing bad start may
#
#
# Continues With Wings
# I'm perfectly open criticism Amazon predatory pricing etc interesting Facebook used Russi
#
#
#
# LOST small male black terrier Lochend Road Highway A Pls contact Pls share hel
#
# Fricken Izzy Israel Martinez
#
#
#
#
# Poor California Democrats Are Turning The State Into A Major Nightmare Liberal policies destroyed quality life
# Excellent
#
# DUN Kota Lama di Kelantan salah satu kerusi DUN PSM bertanding dalam PRU
# Sigue Misa de Vigilia Pascual desde la por Facebook Live por est noche
# Jual kaos polos berbagai macam warna CUMA Rp Info order bisa chat WA Siap kirim ke mana
#
# T Tendoooo mais uma Noite em Danceteria
# Compart en facebook tu twitt Sigo ndolo
# Bank England Test Blockchain Tech Domestic Payments System The Bank England beginning Proof Conce
#
#
# Ah les dejo su Facebook
#
# pero se lo termino enviando denys JAJAJAJAJAJJAJA
#
#
# Hey friends Hari ini bakalan ada clue pertama buat dapetin hadiah e-voucher indomaret sebesar rb amp merchandise menari
# Gila viral pakah di facebook
# I actually think really precious wanted make us Facebook official
#
#
#
# http
# Shruti Sunderraman writes musing THE EXISTENTIAL CRISIS IN MY CEREAL BOWL
#
# N imprensa canalha que censura As redes sociais como Facebook est censurando seus apoia
#
#
# Acho q se deus tivesse vivo ele ia parabenizar por postar corrente religiosa Facebook
# Facebook
#
# I posted new video Facebook
# Got Verified Thanks making smooth
#
# natawa naman ako doon sa memory ko sa facebook HAHAHAHAHA beastmode na beastmode ih HAHAHAHAHA
# Created Design Home Download let's play
#
#
# Want join grapesuit adventures Drop Wine Rack Hiring Fair Wednesday April th Yonge
#
#
# Di Instagram ga ada orang miskin Di Twitter ga ada orang bodoh Di Path ga ada orang susah Di Facebook semua punya temen
# LIBERA A ESTA TIERRA DE LAS GARRAS DEL MAL Venezolanos veneran al Nazareno de San Pablo
#
#
#
# FB
#
#
# Feliz de abril kkkk
# https
#
#
#
#
# NAKAKA-STRESS YUNG NASA FACEBOOK NGAYON YUNG MASASA BEACH NA PUNONG PUNO NG BASURA YAN ANG HIRAP SA ATING MGA PIN
#
#
#
#
# Jumla Diwash par Visesh
# Gracias mami
#
# Facebook Twitter SNS LINEID
#
# Sobre namorar e querer fuxicar celular senha de Facebook e etc Vcs passam adolesc ncia inteira reclamando de pais
#
#
#
# Continues With Wings
# um menino postou facebook que n era pra pesquisar aranha boqueteira estou muito arrependido por ser uma pesso
#
#
#
#
# Quem aqui viveu na poca dos fakes de AFMB sabe oq ter um Facebook inteiro como fam lia e ter conhecido amigos que est
# I added video playlist Why leaked facebook memo dangerous Zuckerberg In depth
#
#
# Cadets water day two national sailing regatta We went live Facebook LEUT Adam Hearsum
# Nigeria Central Bank Warns Against Cryptocurrency Investments Again Nigeria nation popular peculiari
#
#
# Matt Milam person integrity time demonstrates quality courteously respectful others
#
# De San Miguel Arc ngel feed generato usando
#
#
# FM RADIO BERRY FM Facebook
#
#
#
#
# fb page cover
# Blue Moon
# sebel sama instagram ngeluhnya di twitter sebel sama facebook ngeluhnya di twitter sebel sama path ngeluhnya di twitter se
#
# This Love MusicLibrary Digital Vote Top Twitter Chart
#
# This ultimate friendship test
#
#
# You guys better get heads asses befire hits days
#
# Liza Soberano REXONA LIKE SHARE
# opens Facebook sees three April fools Easter jokes closes Facebook
# WE LL GET MOHAE SEASON IF ANY OF THESE MISSIONS IS ACCOMPLISHED VLIVE Youtube Facebook total views
#
# lt Please like share Changmin focus cam Handsome
#
#
# Feliz P scoa queridos clientes e amigos em Marina Pet Groomer
# Facebook Facebook
# Agora que instalei Twitter nem ligo tanto para Whatsapp e nem Facebook
# Easter Egg
# nominated
# Wishing Well Facebook page pm
#
#
#
# Por iniciar vigilia de resurrecci n organiza Llanos
# Welcome
# Wishing Well Facebook page pm
# Zuckerberg criminal
#
#
# The Mask full effect
#
# Hello nd service Easter day service
# Go Eric Clapton One Of The Greatest Fender Users EVER
#
#
#
# Pugeh ingat sa flight niyo bukas mamimiss kita see soon
# facebook bitchin around aint fun
# Tonight Clay I laid couch watched cute animals videos Facebook hour successful saturday night
# wait still facebook
# wait still facebook
# facebook plurk
# de San Juan Bautista Apaseo el Grande Gto Mex
# porque eu ainda tenho facebook se eu n uso
#
#
# carinha facebook Esse eu nunca vi nao kkkkkk
#
#
#
#
#
#
#
#
# Face Facebook Facebook logged SMS texts phone calls without explicitly notifying users
# Seen Facebook I bring twitter I literally cried laughing minutes
# Still
# facebook vs twitter
#
#
#
#
# funny
# In questi anni ho avuto l occasione di conoscere Sergio e sono testimone di quanto sia una grande persona e una risorsa
#
#
#
#
# DEPRESS O A base tratamento geralmente inclui medicamentos psicoterapia ou uma combina dos dois Cada vez
# Korang nak tengok betapa dengkinya melayu Nah kedai makan mak aku baru viral tadi dekat facebook Dia ingat mak aku buka
#
#
#
# HANYA ADA SATU JALAN HIJRAHMU Saudaraku rahimakumullaah perjalanan sejarah umat Islam ibarat sebuah aliran sungai di
# APRLC Livestream NRL Northern Territory Women v NRL SA Women Day Game Senior WOMAN S NRL NT Vs NRL SA
#
# BLACKPINK FAN SIGNING EVENT IN BUNDANG More photos
# Hola te invito leer mi ultima Nota subida la cual intitulo a_porte
#
# These psychographic profiles Colorado voters circa time
# You Better Say It
# link https
#
# Retweeted Federico Di K LA TACTICA D GRAVIA Y NINCI A Natacha Jaitt ES LA D INTRATABLES LA TAPABAN Y NO
#
# I'm perfectly open criticism Amazon predatory pricing etc interesting Facebook used Russi
#
# I imagine windmill farms blades made solar panels towers covered materials capable trapping carb
#
#
#
# link https
#
#
# Thuparuth plz
# PDP Challenges President Buhari To Explain Stolen Trillion Under Him As Petroleum Minister Nigeria main oppositio
# In five years Facebook Apple Amazon Netflix Google doubled effect S amp
# MY SISTER WENT LIVE ON FACEBOOK AND BEAT HER BOYFRIEND ASS LMAOOOO
#
#
# Smooth
# Coitado v KKKKKKKKKKK
# Comunista patrocinando post Facebook
# Read Gujarati businessman buys land Assam builds resort serves foreigners amp keeps locals Next
#
# APRLC Livestream NRL Victoria Women v NRL WA Women Day Game Senior WOMANS NRL VIC Vs NRL WA

# %%
data = pd.read_csv("Twitter/TestData.csv")
actual_data["text"] = data["text"]
f = open("Twitter/TestData.txt","w+")

for text in actual_data.text:
    f.write(text)
f.close()
